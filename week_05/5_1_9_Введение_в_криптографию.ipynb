# %%
# @title https://stepik.org/lesson/289856/step/9
a = [x.lower() for x in 'Джон истинный Таргариен и законный наследник Вестероса' if x != ' ']
''.join(a[i + j*8] for i in range(8) for j in range(6))
# Out:
# 'днаксежнролсоыинетнйендеитнынрсаийиотрзнксигаава'
