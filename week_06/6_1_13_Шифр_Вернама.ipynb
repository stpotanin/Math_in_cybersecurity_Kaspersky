# %% [markdown]
# https://stepik.org/lesson/288961/step/13

# %%
message, gamma = '03 3E 30 3C 38 3F 36', 0x51
# res = [m.hex() ^ gamma for m in message.split()]
''.join([chr(int(m, 16) ^ gamma) for m in message.split()])
# Out:
# 'Roaming'

# %%
chr(82)
# Out:
# 'R'
